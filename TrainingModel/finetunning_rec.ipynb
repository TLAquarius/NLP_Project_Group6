# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/PaddlePaddle/PaddleOCR.git
# Out:
# fatal: destination path 'PaddleOCR' already exists and is not an empty directory.

# %%
# !pip install -q pyclipper lmdb rapidfuzz paddlepaddle-gpu paddleocr
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.2/912.2 kB 43.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 87.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.7/544.7 kB 39.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 22.3 MB/s eta 0:00:00
# ...

# %%
# import zipfile
# import os

# # Đường dẫn đến file zip trên Google Drive
# zip_path = '/content/drive/MyDrive/dataset.zip'

# # Thư mục đích để giải nén
# extract_path = '/content/drive/MyDrive/PaddleOCR'

# # Giải nén file zip
# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_path)

# # Kiểm tra các tệp trong thư mục đã giải nén
# for file_name in os.listdir(extract_path):
#     print(file_name)
# Out:
# .git
# .clang_format.hook
# .github
# .gitignore
# .pre-commit-config.yaml
# .style.yapf
# LICENSE
# MANIFEST.in
# README.md
# README_en.md
# __init__.py
# applications
# benchmark
# configs
# deploy
# doc
# docs
# mkdocs.yml
# overrides
# paddleocr.py
# ppocr
# ppstructure
# pyproject.toml
# requirements.txt
# setup.py
# test_tipc
# tests
# tools
# train.sh
# dataset
# .ipynb_checkpoints

# %%
import cv2
import os
import numpy as np
import json
from tqdm import tqdm
import matplotlib.pyplot as plt
from imutils import perspective
from paddleocr import PaddleOCR,draw_ocr
from PIL import Image
import paddle

# %%
paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.

# %%
# !wget -P pretrained_models/recognition2/ https://paddleocr.bj.bcebos.com/PP-OCRv3/chinese/ch_PP-OCRv3_rec_train.tar
# Out:
# --2024-12-27 16:44:38--  https://paddleocr.bj.bcebos.com/PP-OCRv3/chinese/ch_PP-OCRv3_rec_train.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.47.176, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 287467520 (274M) [application/x-tar]
# Saving to: ‘pretrained_models/recognition2/ch_PP-OCRv3_rec_train.tar’
#
# ch_PP-OCRv3_rec_tra 100%[===================>] 274.15M  15.5MB/s    in 36s
#
# 2024-12-27 16:45:15 (7.67 MB/s) - ‘pretrained_models/recognition2/ch_PP-OCRv3_rec_train.tar’ saved [287467520/287467520]

# %%
# !tar -xf pretrained_models/recognition/ch_PP-OCRv3_rec_train.tar -C pretrained_models/recognition2 && rm -rf pretrained_models/recognition2/en_PP-OCRv3_rec_train.tar

# %%
# !python3 PaddleOCR/tools/train.py -c /content/drive/MyDrive/PaddleOCR/dataset2/ch_PP-OCRv3_rec.yml
# Out:
# [2024/12/28 08:01:36] ppocr INFO: Architecture :
# [2024/12/28 08:01:37] ppocr INFO:     Backbone :
# [2024/12/28 08:01:37] ppocr INFO:         last_conv_stride : [1, 2]
# [2024/12/28 08:01:37] ppocr INFO:         last_pool_kernel_size : [2, 2]
# [2024/12/28 08:01:37] ppocr INFO:         last_pool_type : avg
# [2024/12/28 08:01:37] ppocr INFO:         name : MobileNetV1Enhance
# [2024/12/28 08:01:37] ppocr INFO:         scale : 0.5
# [2024/12/28 08:01:37] ppocr INFO:     Head :
# [2024/12/28 08:01:37] ppocr INFO:         head_list :
# [2024/12/28 08:01:37] ppocr INFO:             CTCHead :
# [2024/12/28 08:01:37] ppocr INFO:                 Head :
# [2024/12/28 08:01:37] ppocr INFO:                     fc_decay : 1e-05
# [2024/12/28 08:01:37] ppocr INFO:                 Neck :
# [2024/12/28 08:01:37] ppocr INFO:                     depth : 2
# [2024/12/28 08:01:37] ppocr INFO:                     dims : 64
# [2024/12/28 08:01:37] ppocr INFO:                     hidden_dims : 120
# ...

# %%
# !python3 PaddleOCR/tools/export_model.py -c /content/drive/MyDrive/PaddleOCR/dataset/ch_PP-OCRv3_rec.yml -o Global.pretrained_model=output/rec_ppocr_v3/best_model/model.pdparams  Global.save_inference_dir=models/recognition
# Out:
# W1227 04:18:53.291143 22779 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.0, Driver API Version: 12.2, Runtime API Version: 11.8
# W1227 04:18:53.292388 22779 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# [2024/12/27 04:18:53] ppocr INFO: load pretrain successful from output/rec_ppocr_v3/best_model/model
# [2024/12/27 04:18:54] ppocr INFO: Export inference config file to models/recognition/inference.yml
# I1227 04:18:56.108587 22779 program_interpreter.cc:212] New Executor is Running.
# [2024/12/27 04:18:56] ppocr INFO: inference model is saved to models/recognition/inference
